# %%
"""
Modified LSTM to work on a bigger multiclass extract and tuned it a bit.

This is the final LSTM model we ended up using.

Author: Wesley
"""
import numpy as np
import pandas as pd
import seaborn as sns
import statistics as stats
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_score, recall_score, f1_score
import io # StringIO
import keras
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout, Flatten, Conv1D, Conv2D, GlobalMaxPooling2D,GlobalMaxPooling1D, MaxPool1D, MaxPool2D
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt

import tensorflow_addons as tfa

from sklearn.preprocessing import MinMaxScaler, StandardScaler

from sklearn.metrics import classification_report

# %%
binary_train = pd.read_csv("binary_train.csv")
binary_test = pd.read_csv("binary_test.csv")

# %%
# Encode attack labels to int and save as array to be used later.

binary_train[' Label'] = binary_train[' Label'].apply(lambda l : 0 if l == 'BENIGN' else 1)
binary_test[' Label'] = binary_test[' Label'].apply(lambda l : 0 if l == 'BENIGN' else 1)

binary_labels = ["BENIGN", "ATTACK"]

# %%
y_train = binary_train[" Label"].copy()
X_train = binary_train.drop([" Label"], axis=1)

y_test = binary_test[" Label"].copy()
X_test = binary_test.drop([" Label"], axis=1)

# %%
scal = StandardScaler()
scal = scal.fit(X_train)
X_test = scal.transform(X_test)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size = 0.125, stratify=y_train, random_state=42)
X_train = scal.fit_transform(X_train)
X_val = scal.transform(X_val)

# %%
n_feat = 80
X_tr = np.reshape(X_train, (len(X_train), n_feat, 1))
X_vl = np.reshape(X_val, (len(X_val), n_feat, 1))
X_tst = np.reshape(X_test, (len(X_test), n_feat, 1))

# %%
print(X_tr.shape)
print(y_train.shape)
# Out:
# (139993, 80, 1)
# (139993,)

# %%
model = keras.Sequential()
model.add(Conv1D(filters = 512, kernel_size = 3, activation='relu', input_shape=X_tr.shape[1:3]))
#model.add(MaxPool1D(pool_size=2))
#model.add(Conv1D(filters = 128, kernel_size = 3, activation='relu'))
##model.add(MaxPool1D(pool_size=2))
#model.add(Conv1D(filters = 256, kernel_size = 3, activation='relu'))
#model.add(MaxPool1D(pool_size=2))
#model.add(Conv1D(filters = 512, kernel_size = 3, activation='relu'))
model.add(MaxPool1D(pool_size=2))
model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dense(256, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(16, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

opt = keras.optimizers.Adadelta(learning_rate=0.1)
#opt = tfa.optimizers.AdamW(learning_rate=0.001, weight_decay = 5e-3)
reduce_lr = keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5,
                              patience=3, min_lr=0.000001)
checkpoint_filepath = './checkpoint'
model_checkpoint_callback = keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=True,
    monitor='val_loss',
    mode='min',
    save_best_only=True)

model.compile(optimizer=opt, loss='binary_crossentropy', metrics=['binary_accuracy'])
model.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_18 (Conv1D)          (None, 78, 512)           2048
#
#  max_pooling1d_18 (MaxPoolin  (None, 39, 512)          0
#  g1D)
#
#  flatten_9 (Flatten)         (None, 19968)             0
#
#  dense_36 (Dense)            (None, 512)               10224128
#
#  dense_37 (Dense)            (None, 256)               131328
#
#  dense_38 (Dense)            (None, 128)               32896
#
#  dense_39 (Dense)            (None, 64)                8256
#
#  dense_40 (Dense)            (None, 16)                1040
#
#  dense_41 (Dense)            (None, 1)                 17
#
# =================================================================
# Total params: 10,399,713
# Trainable params: 10,399,713
# Non-trainable params: 0
# _________________________________________________________________

# %%
history=model.fit(X_tr, y_train.to_numpy(), validation_data = (X_vl, y_val.to_numpy()), batch_size=128, epochs=100, callbacks = [reduce_lr,model_checkpoint_callback])
# Out:
# Epoch 1/100
# 1094/1094 [==============================] - 13s 11ms/step - loss: 0.0262 - binary_accuracy: 0.9967 - val_loss: 0.0093 - val_binary_accuracy: 0.9980 - lr: 0.1000
# Epoch 2/100
# 1094/1094 [==============================] - 12s 11ms/step - loss: 0.0088 - binary_accuracy: 0.9982 - val_loss: 0.0080 - val_binary_accuracy: 0.9983 - lr: 0.1000
# Epoch 3/100
# 1094/1094 [==============================] - 12s 11ms/step - loss: 0.0081 - binary_accuracy: 0.9982 - val_loss: 0.0076 - val_binary_accuracy: 0.9987 - lr: 0.1000
# Epoch 4/100
# 1094/1094 [==============================] - 12s 11ms/step - loss: 0.0074 - binary_accuracy: 0.9984 - val_loss: 0.0080 - val_binary_accuracy: 0.9982 - lr: 0.1000
# Epoch 5/100
# 1094/1094 [==============================] - 12s 11ms/step - loss: 0.0070 - binary_accuracy: 0.9984 - val_loss: 0.0070 - val_binary_accuracy: 0.9986 - lr: 0.1000
# Epoch 6/100
# 1094/1094 [==============================] - 12s 11ms/step - loss: 0.0068 - binary_accuracy: 0.9983 - val_loss: 0.0064 - val_binary_accuracy: 0.9985 - lr: 0.1000
# Epoch 7/100
# 1094/1094 [==============================] - 12s 11ms/step - loss: 0.0065 - binary_accuracy: 0.9985 - val_loss: 0.0067 - val_binary_accuracy: 0.9987 - lr: 0.1000
# Epoch 8/100
# 1094/1094 [==============================] - 12s 11ms/step - loss: 0.0061 - binary_accuracy: 0.9985 - val_loss: 0.0061 - val_binary_accuracy: 0.9986 - lr: 0.1000
# Epoch 9/100
# 1094/1094 [==============================] - 12s 11ms/step - loss: 0.0059 - binary_accuracy: 0.9986 - val_loss: 0.0060 - val_binary_accuracy: 0.9988 - lr: 0.1000
# Epoch 10/100
# 1094/1094 [==============================] - 12s 11ms/step - loss: 0.0057 - binary_accuracy: 0.9986 - val_loss: 0.0067 - val_binary_accuracy: 0.9987 - lr: 0.1000
# Epoch 11/100
# 1094/1094 [==============================] - 12s 11ms/step - loss: 0.0053 - binary_accuracy: 0.9987 - val_loss: 0.0054 - val_binary_accuracy: 0.9991 - lr: 0.1000
# Epoch 12/100
# 1094/1094 [==============================] - 12s 11ms/step - loss: 0.0052 - binary_accuracy: 0.9989 - val_loss: 0.0068 - val_binary_accuracy: 0.9990 - lr: 0.1000
# Epoch 13/100
# 1094/1094 [==============================] - 12s 11ms/step - loss: 0.0047 - binary_accuracy: 0.9990 - val_loss: 0.0058 - val_binary_accuracy: 0.9991 - lr: 0.1000
# Epoch 14/100
# 1094/1094 [==============================] - 12s 11ms/step - loss: 0.0047 - binary_accuracy: 0.9990 - val_loss: 0.0056 - val_binary_accuracy: 0.9990 - lr: 0.1000
# Epoch 15/100
# 1094/1094 [==============================] - 12s 11ms/step - loss: 0.0039 - binary_accuracy: 0.9992 - val_loss: 0.0046 - val_binary_accuracy: 0.9991 - lr: 0.0500
# Epoch 16/100
# 1094/1094 [==============================] - 12s 11ms/step - loss: 0.0038 - binary_accuracy: 0.9993 - val_loss: 0.0055 - val_binary_accuracy: 0.9991 - lr: 0.0500
# Epoch 17/100
# 1094/1094 [==============================] - 12s 11ms/step - loss: 0.0036 - binary_accuracy: 0.9993 - val_loss: 0.0047 - val_binary_accuracy: 0.9991 - lr: 0.0500
# Epoch 18/100
# 1094/1094 [==============================] - 12s 11ms/step - loss: 0.0035 - binary_accuracy: 0.9993 - val_loss: 0.0045 - val_binary_accuracy: 0.9991 - lr: 0.0500
# Epoch 19/100
# 1094/1094 [==============================] - 12s 11ms/step - loss: 0.0033 - binary_accuracy: 0.9993 - val_loss: 0.0044 - val_binary_accuracy: 0.9991 - lr: 0.0500
# Epoch 20/100
# 1094/1094 [==============================] - 12s 11ms/step - loss: 0.0032 - binary_accuracy: 0.9994 - val_loss: 0.0043 - val_binary_accuracy: 0.9991 - lr: 0.0500
# Epoch 21/100
# 1094/1094 [==============================] - 12s 11ms/step - loss: 0.0031 - binary_accuracy: 0.9994 - val_loss: 0.0041 - val_binary_accuracy: 0.9995 - lr: 0.0500
# Epoch 22/100
# 1094/1094 [==============================] - 12s 11ms/step - loss: 0.0029 - binary_accuracy: 0.9995 - val_loss: 0.0042 - val_binary_accuracy: 0.9992 - lr: 0.0500
# Epoch 23/100
# 1094/1094 [==============================] - 12s 11ms/step - loss: 0.0029 - binary_accuracy: 0.9995 - val_loss: 0.0041 - val_binary_accuracy: 0.9995 - lr: 0.0500
# Epoch 24/100
# 1094/1094 [==============================] - 12s 11ms/step - loss: 0.0028 - binary_accuracy: 0.9995 - val_loss: 0.0040 - val_binary_accuracy: 0.9995 - lr: 0.0500
# Epoch 25/100
# 1094/1094 [==============================] - 12s 11ms/step - loss: 0.0027 - binary_accuracy: 0.9995 - val_loss: 0.0041 - val_binary_accuracy: 0.9995 - lr: 0.0500
# Epoch 26/100
# 1094/1094 [==============================] - 12s 11ms/step - loss: 0.0027 - binary_accuracy: 0.9995 - val_loss: 0.0040 - val_binary_accuracy: 0.9995 - lr: 0.0500
# Epoch 27/100
# 1094/1094 [==============================] - 12s 11ms/step - loss: 0.0027 - binary_accuracy: 0.9995 - val_loss: 0.0039 - val_binary_accuracy: 0.9995 - lr: 0.0500
# Epoch 28/100
# 1094/1094 [==============================] - 12s 11ms/step - loss: 0.0025 - binary_accuracy: 0.9996 - val_loss: 0.0040 - val_binary_accuracy: 0.9995 - lr: 0.0250
# Epoch 29/100
# 1094/1094 [==============================] - 12s 11ms/step - loss: 0.0025 - binary_accuracy: 0.9996 - val_loss: 0.0040 - val_binary_accuracy: 0.9995 - lr: 0.0250
# Epoch 30/100
# 1094/1094 [==============================] - 12s 11ms/step - loss: 0.0025 - binary_accuracy: 0.9996 - val_loss: 0.0040 - val_binary_accuracy: 0.9995 - lr: 0.0250
# Epoch 31/100
# 1094/1094 [==============================] - 12s 11ms/step - loss: 0.0024 - binary_accuracy: 0.9996 - val_loss: 0.0040 - val_binary_accuracy: 0.9995 - lr: 0.0125
# Epoch 32/100
# 1094/1094 [==============================] - 12s 11ms/step - loss: 0.0024 - binary_accuracy: 0.9996 - val_loss: 0.0040 - val_binary_accuracy: 0.9995 - lr: 0.0125
# Epoch 33/100
# 1094/1094 [==============================] - 12s 11ms/step - loss: 0.0024 - binary_accuracy: 0.9996 - val_loss: 0.0040 - val_binary_accuracy: 0.9995 - lr: 0.0125
# Epoch 34/100
# 1094/1094 [==============================] - 12s 11ms/step - loss: 0.0024 - binary_accuracy: 0.9996 - val_loss: 0.0040 - val_binary_accuracy: 0.9995 - lr: 0.0063
# Epoch 35/100
# 1094/1094 [==============================] - 12s 11ms/step - loss: 0.0024 - binary_accuracy: 0.9996 - val_loss: 0.0040 - val_binary_accuracy: 0.9995 - lr: 0.0063
# Epoch 36/100
# 1094/1094 [==============================] - 12s 11ms/step - loss: 0.0024 - binary_accuracy: 0.9996 - val_loss: 0.0040 - val_binary_accuracy: 0.9995 - lr: 0.0063
# Epoch 37/100
# 1094/1094 [==============================] - 12s 11ms/step - loss: 0.0024 - binary_accuracy: 0.9996 - val_loss: 0.0040 - val_binary_accuracy: 0.9995 - lr: 0.0031
# Epoch 38/100
# 1094/1094 [==============================] - 12s 11ms/step - loss: 0.0023 - binary_accuracy: 0.9996 - val_loss: 0.0040 - val_binary_accuracy: 0.9995 - lr: 0.0031
# Epoch 39/100
# 1094/1094 [==============================] - 12s 11ms/step - loss: 0.0023 - binary_accuracy: 0.9996 - val_loss: 0.0040 - val_binary_accuracy: 0.9995 - lr: 0.0031
# Epoch 40/100
# 1094/1094 [==============================] - 12s 11ms/step - loss: 0.0023 - binary_accuracy: 0.9996 - val_loss: 0.0040 - val_binary_accuracy: 0.9995 - lr: 0.0016
# Epoch 41/100
# 1094/1094 [==============================] - 12s 11ms/step - loss: 0.0023 - binary_accuracy: 0.9996 - val_loss: 0.0040 - val_binary_accuracy: 0.9995 - lr: 0.0016
# Epoch 42/100
# 1094/1094 [==============================] - 12s 11ms/step - loss: 0.0023 - binary_accuracy: 0.9996 - val_loss: 0.0040 - val_binary_accuracy: 0.9995 - lr: 0.0016
# Epoch 43/100
# 1094/1094 [==============================] - 12s 11ms/step - loss: 0.0023 - binary_accuracy: 0.9996 - val_loss: 0.0040 - val_binary_accuracy: 0.9995 - lr: 7.8125e-04
# Epoch 44/100
# 1094/1094 [==============================] - 12s 11ms/step - loss: 0.0023 - binary_accuracy: 0.9996 - val_loss: 0.0040 - val_binary_accuracy: 0.9995 - lr: 7.8125e-04
# Epoch 45/100
# 1094/1094 [==============================] - 12s 11ms/step - loss: 0.0023 - binary_accuracy: 0.9996 - val_loss: 0.0040 - val_binary_accuracy: 0.9995 - lr: 7.8125e-04
# Epoch 46/100
# 1094/1094 [==============================] - 12s 11ms/step - loss: 0.0023 - binary_accuracy: 0.9996 - val_loss: 0.0040 - val_binary_accuracy: 0.9995 - lr: 3.9063e-04
# Epoch 47/100
# 1094/1094 [==============================] - 12s 11ms/step - loss: 0.0023 - binary_accuracy: 0.9996 - val_loss: 0.0040 - val_binary_accuracy: 0.9995 - lr: 3.9063e-04
# Epoch 48/100
# 1094/1094 [==============================] - 12s 11ms/step - loss: 0.0023 - binary_accuracy: 0.9996 - val_loss: 0.0040 - val_binary_accuracy: 0.9995 - lr: 3.9063e-04
# Epoch 49/100
# 1094/1094 [==============================] - 12s 11ms/step - loss: 0.0023 - binary_accuracy: 0.9996 - val_loss: 0.0040 - val_binary_accuracy: 0.9995 - lr: 1.9531e-04
# Epoch 50/100
# 1094/1094 [==============================] - 12s 11ms/step - loss: 0.0023 - binary_accuracy: 0.9996 - val_loss: 0.0040 - val_binary_accuracy: 0.9995 - lr: 1.9531e-04
# Epoch 51/100
# 1094/1094 [==============================] - 12s 11ms/step - loss: 0.0023 - binary_accuracy: 0.9996 - val_loss: 0.0040 - val_binary_accuracy: 0.9995 - lr: 1.9531e-04
# Epoch 52/100
# 1094/1094 [==============================] - 12s 11ms/step - loss: 0.0023 - binary_accuracy: 0.9996 - val_loss: 0.0040 - val_binary_accuracy: 0.9995 - lr: 9.7656e-05
# Epoch 53/100
# 1094/1094 [==============================] - 12s 11ms/step - loss: 0.0023 - binary_accuracy: 0.9996 - val_loss: 0.0040 - val_binary_accuracy: 0.9995 - lr: 9.7656e-05
# Epoch 54/100
# 1094/1094 [==============================] - 12s 11ms/step - loss: 0.0023 - binary_accuracy: 0.9996 - val_loss: 0.0040 - val_binary_accuracy: 0.9995 - lr: 9.7656e-05
# Epoch 55/100
# 1094/1094 [==============================] - 12s 11ms/step - loss: 0.0023 - binary_accuracy: 0.9996 - val_loss: 0.0040 - val_binary_accuracy: 0.9995 - lr: 4.8828e-05
# Epoch 56/100
# 1094/1094 [==============================] - 12s 11ms/step - loss: 0.0023 - binary_accuracy: 0.9996 - val_loss: 0.0040 - val_binary_accuracy: 0.9995 - lr: 4.8828e-05
# Epoch 57/100
# 1094/1094 [==============================] - 12s 11ms/step - loss: 0.0023 - binary_accuracy: 0.9996 - val_loss: 0.0040 - val_binary_accuracy: 0.9995 - lr: 4.8828e-05
# Epoch 58/100
# 1094/1094 [==============================] - 12s 11ms/step - loss: 0.0023 - binary_accuracy: 0.9996 - val_loss: 0.0040 - val_binary_accuracy: 0.9995 - lr: 2.4414e-05
# Epoch 59/100
# 1094/1094 [==============================] - 12s 11ms/step - loss: 0.0023 - binary_accuracy: 0.9996 - val_loss: 0.0040 - val_binary_accuracy: 0.9995 - lr: 2.4414e-05
# Epoch 60/100
# 1094/1094 [==============================] - 12s 11ms/step - loss: 0.0023 - binary_accuracy: 0.9996 - val_loss: 0.0040 - val_binary_accuracy: 0.9995 - lr: 2.4414e-05
# Epoch 61/100
# 1094/1094 [==============================] - 12s 11ms/step - loss: 0.0023 - binary_accuracy: 0.9996 - val_loss: 0.0040 - val_binary_accuracy: 0.9995 - lr: 1.2207e-05
# Epoch 62/100
# 1094/1094 [==============================] - 12s 11ms/step - loss: 0.0023 - binary_accuracy: 0.9996 - val_loss: 0.0040 - val_binary_accuracy: 0.9995 - lr: 1.2207e-05
# Epoch 63/100
# 1094/1094 [==============================] - 12s 11ms/step - loss: 0.0023 - binary_accuracy: 0.9996 - val_loss: 0.0040 - val_binary_accuracy: 0.9995 - lr: 1.2207e-05
# Epoch 64/100
# 1094/1094 [==============================] - 12s 11ms/step - loss: 0.0023 - binary_accuracy: 0.9996 - val_loss: 0.0040 - val_binary_accuracy: 0.9995 - lr: 6.1035e-06
# Epoch 65/100
# 1094/1094 [==============================] - 12s 11ms/step - loss: 0.0023 - binary_accuracy: 0.9996 - val_loss: 0.0040 - val_binary_accuracy: 0.9995 - lr: 6.1035e-06
# Epoch 66/100
# 1094/1094 [==============================] - 12s 11ms/step - loss: 0.0023 - binary_accuracy: 0.9996 - val_loss: 0.0040 - val_binary_accuracy: 0.9995 - lr: 6.1035e-06
# Epoch 67/100
# 1094/1094 [==============================] - 12s 11ms/step - loss: 0.0023 - binary_accuracy: 0.9996 - val_loss: 0.0040 - val_binary_accuracy: 0.9995 - lr: 3.0518e-06
# Epoch 68/100
# 1094/1094 [==============================] - 12s 11ms/step - loss: 0.0023 - binary_accuracy: 0.9996 - val_loss: 0.0040 - val_binary_accuracy: 0.9995 - lr: 3.0518e-06
# Epoch 69/100
# 1094/1094 [==============================] - 12s 11ms/step - loss: 0.0023 - binary_accuracy: 0.9996 - val_loss: 0.0040 - val_binary_accuracy: 0.9995 - lr: 3.0518e-06
# Epoch 70/100
# 1094/1094 [==============================] - 12s 11ms/step - loss: 0.0023 - binary_accuracy: 0.9996 - val_loss: 0.0040 - val_binary_accuracy: 0.9995 - lr: 1.5259e-06
# Epoch 71/100
# 1094/1094 [==============================] - 12s 11ms/step - loss: 0.0023 - binary_accuracy: 0.9996 - val_loss: 0.0040 - val_binary_accuracy: 0.9995 - lr: 1.5259e-06
# Epoch 72/100
# 1094/1094 [==============================] - 12s 11ms/step - loss: 0.0023 - binary_accuracy: 0.9996 - val_loss: 0.0040 - val_binary_accuracy: 0.9995 - lr: 1.5259e-06
# Epoch 73/100
# 1094/1094 [==============================] - 12s 11ms/step - loss: 0.0023 - binary_accuracy: 0.9996 - val_loss: 0.0040 - val_binary_accuracy: 0.9995 - lr: 1.0000e-06
# Epoch 74/100
# 1094/1094 [==============================] - 12s 11ms/step - loss: 0.0023 - binary_accuracy: 0.9996 - val_loss: 0.0040 - val_binary_accuracy: 0.9995 - lr: 1.0000e-06
# Epoch 75/100
# 1094/1094 [==============================] - 12s 11ms/step - loss: 0.0023 - binary_accuracy: 0.9996 - val_loss: 0.0040 - val_binary_accuracy: 0.9995 - lr: 1.0000e-06
# Epoch 76/100
# 1094/1094 [==============================] - 12s 11ms/step - loss: 0.0023 - binary_accuracy: 0.9996 - val_loss: 0.0040 - val_binary_accuracy: 0.9995 - lr: 1.0000e-06
# Epoch 77/100
# 1094/1094 [==============================] - 12s 11ms/step - loss: 0.0023 - binary_accuracy: 0.9996 - val_loss: 0.0040 - val_binary_accuracy: 0.9995 - lr: 1.0000e-06
# Epoch 78/100
# 1094/1094 [==============================] - 12s 11ms/step - loss: 0.0023 - binary_accuracy: 0.9996 - val_loss: 0.0040 - val_binary_accuracy: 0.9995 - lr: 1.0000e-06
# Epoch 79/100
# 1094/1094 [==============================] - 12s 11ms/step - loss: 0.0023 - binary_accuracy: 0.9996 - val_loss: 0.0040 - val_binary_accuracy: 0.9995 - lr: 1.0000e-06
# Epoch 80/100
# 1094/1094 [==============================] - 12s 11ms/step - loss: 0.0023 - binary_accuracy: 0.9996 - val_loss: 0.0040 - val_binary_accuracy: 0.9995 - lr: 1.0000e-06
# Epoch 81/100
# 1094/1094 [==============================] - 12s 11ms/step - loss: 0.0023 - binary_accuracy: 0.9996 - val_loss: 0.0040 - val_binary_accuracy: 0.9995 - lr: 1.0000e-06
# Epoch 82/100
# 1094/1094 [==============================] - 12s 11ms/step - loss: 0.0023 - binary_accuracy: 0.9996 - val_loss: 0.0040 - val_binary_accuracy: 0.9995 - lr: 1.0000e-06
# Epoch 83/100
# 1094/1094 [==============================] - 12s 11ms/step - loss: 0.0023 - binary_accuracy: 0.9996 - val_loss: 0.0040 - val_binary_accuracy: 0.9995 - lr: 1.0000e-06
# Epoch 84/100
# 1094/1094 [==============================] - 12s 11ms/step - loss: 0.0023 - binary_accuracy: 0.9996 - val_loss: 0.0040 - val_binary_accuracy: 0.9995 - lr: 1.0000e-06
# Epoch 85/100
# 1094/1094 [==============================] - 12s 11ms/step - loss: 0.0023 - binary_accuracy: 0.9996 - val_loss: 0.0040 - val_binary_accuracy: 0.9995 - lr: 1.0000e-06
# Epoch 86/100
# 1094/1094 [==============================] - 12s 11ms/step - loss: 0.0023 - binary_accuracy: 0.9996 - val_loss: 0.0040 - val_binary_accuracy: 0.9995 - lr: 1.0000e-06
# Epoch 87/100
# 1094/1094 [==============================] - 12s 11ms/step - loss: 0.0023 - binary_accuracy: 0.9996 - val_loss: 0.0040 - val_binary_accuracy: 0.9995 - lr: 1.0000e-06
# Epoch 88/100
# 1094/1094 [==============================] - 12s 11ms/step - loss: 0.0023 - binary_accuracy: 0.9996 - val_loss: 0.0040 - val_binary_accuracy: 0.9995 - lr: 1.0000e-06
# Epoch 89/100
# 1094/1094 [==============================] - 12s 11ms/step - loss: 0.0023 - binary_accuracy: 0.9996 - val_loss: 0.0040 - val_binary_accuracy: 0.9995 - lr: 1.0000e-06
# Epoch 90/100
# 1094/1094 [==============================] - 12s 11ms/step - loss: 0.0023 - binary_accuracy: 0.9996 - val_loss: 0.0040 - val_binary_accuracy: 0.9995 - lr: 1.0000e-06
# Epoch 91/100
# 1094/1094 [==============================] - 12s 11ms/step - loss: 0.0023 - binary_accuracy: 0.9996 - val_loss: 0.0040 - val_binary_accuracy: 0.9995 - lr: 1.0000e-06
# Epoch 92/100
# 1094/1094 [==============================] - 12s 11ms/step - loss: 0.0023 - binary_accuracy: 0.9996 - val_loss: 0.0040 - val_binary_accuracy: 0.9995 - lr: 1.0000e-06
# Epoch 93/100
# 1094/1094 [==============================] - 12s 11ms/step - loss: 0.0023 - binary_accuracy: 0.9996 - val_loss: 0.0040 - val_binary_accuracy: 0.9995 - lr: 1.0000e-06
# Epoch 94/100
# 1094/1094 [==============================] - 12s 11ms/step - loss: 0.0023 - binary_accuracy: 0.9996 - val_loss: 0.0040 - val_binary_accuracy: 0.9995 - lr: 1.0000e-06
# Epoch 95/100
# 1094/1094 [==============================] - 12s 11ms/step - loss: 0.0023 - binary_accuracy: 0.9996 - val_loss: 0.0040 - val_binary_accuracy: 0.9995 - lr: 1.0000e-06
# Epoch 96/100
# 1094/1094 [==============================] - 12s 11ms/step - loss: 0.0023 - binary_accuracy: 0.9996 - val_loss: 0.0040 - val_binary_accuracy: 0.9995 - lr: 1.0000e-06
# Epoch 97/100
# 1094/1094 [==============================] - 12s 11ms/step - loss: 0.0023 - binary_accuracy: 0.9996 - val_loss: 0.0040 - val_binary_accuracy: 0.9995 - lr: 1.0000e-06
# Epoch 98/100
# 1094/1094 [==============================] - 12s 11ms/step - loss: 0.0023 - binary_accuracy: 0.9996 - val_loss: 0.0040 - val_binary_accuracy: 0.9995 - lr: 1.0000e-06
# Epoch 99/100
# 1094/1094 [==============================] - 12s 11ms/step - loss: 0.0023 - binary_accuracy: 0.9996 - val_loss: 0.0040 - val_binary_accuracy: 0.9995 - lr: 1.0000e-06
# Epoch 100/100
# 1094/1094 [==============================] - 12s 11ms/step - loss: 0.0023 - binary_accuracy: 0.9996 - val_loss: 0.0040 - val_binary_accuracy: 0.9995 - lr: 1.0000e-06

# %%
#history=model.fit(X_tr, y_train.to_numpy(), batch_size=len(X_tr), epochs=10)
path_new_model = "CNN_binary_final.h5"

#Save final model
model.save(path_new_model)

# %%
# list all data in history
print(history.history.keys())
# summarize history for accuracy
plt.plot(history.history['binary_accuracy'])
plt.plot(history.history['binary_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'binary_accuracy', 'val_loss', 'val_binary_accuracy', 'lr'])

# %%
#Test predictions
#model.load_weights(checkpoint_filepath)
prediction = model.predict(X_tst)
# Out:
# 1250/1250 [==============================] - 2s 2ms/step

# %%
pred = [1 if prediction[i] >= 0.5 else 0 for i in range(len(prediction))]
#pred = [np.argmax(x) for x in prediction]
pd.Series(pred).value_counts()
# Out:
# 0    20004
# 1    19995
# dtype: int64

# %%
print(classification_report(y_test.to_numpy(), pred, digits=6,target_names=binary_labels))
# Out:
#               precision    recall  f1-score   support
#
#       BENIGN   0.999650  0.999900  0.999775     19999
#       ATTACK   0.999900  0.999650  0.999775     20000
#
#     accuracy                       0.999775     39999
#    macro avg   0.999775  0.999775  0.999775     39999
# weighted avg   0.999775  0.999775  0.999775     39999

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

cm = confusion_matrix(y_test, pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=binary_labels)
fig, ax = plt.subplots(figsize=(12,12))
disp.plot(ax=ax)
plt.savefig("confusion_binary_cnn.png")

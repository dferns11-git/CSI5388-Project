# %%
import numpy as np
import pandas as pd
import dask.dataframe as dd # get dask with: pip install "dask[complete]"
from os import listdir
from os.path import isfile, join
import os

# %%
# Assumes we've placed program in root of dataset folder, where both days are subdirectories.
path1 = os.getcwd() + "/01-12"
path2 = os.getcwd() + "/03-11"

# %%
# Get list of files in each directory.
fileList = [path1 + '/' + f for f in listdir(path1) if isfile(join(path1, f))]
fileList2 = [path2 + '/' + f for f in listdir(path2) if isfile(join(path2, f))]

# %%
"""
This function extracts an equal amount of benign and attack data for each day and forms the train/test sets.

Needs Dask due to how large many of the datasets are.
"""
def extract(fileList):

    print("Beginning extraction of benign data...")
    # First pass aggregates BENIGN data.
    i = 0
    outFrame = None
    for f in fileList:
        df = dd.read_csv(f, dtype={'SimillarHTTP': 'object'})
        lind = f.rfind('/')
        slind = f.rfind('/', 0,lind-1)
        print(f[slind:])
        #print(f"{df[' Label'].value_counts().compute()}\n")

        # Pull benign samples out and get their quantity.
        ben_df = df[df[' Label'] == 'BENIGN']

        if i == 0:
            outFrame = ben_df
            i += 1

        else:    
            outFrame = dd.concat([outFrame, ben_df])

        #print(f"Aggregated df stats: {outFrame[' Label'].value_counts().compute()}\n")

    # Get the total count of BENIGN samples that we've aggregated.
    shben = outFrame.shape
    ben_num = shben[0].compute()
    print(f"Number of Benign samples aggregated: {ben_num}")

    print("Beginning extraction of attack data...")

    # Second pass pulls out attack data equal in quantity to the count of benign data that we've gathered.
    for f in fileList:
        df = dd.read_csv(f, dtype={'SimillarHTTP': 'object'})
        lind = f.rfind('/')
        slind = f.rfind('/', 0,lind-1)
        print(f[slind:])
  
        # Get list of label categories
        cats = list(set(list(df[' Label'])))

        # Go through non-benign categories and add a subsample equal in quantity to the number of benign samples.
        for cat in cats:

            if cat != "BENIGN":

                print(f"Appending data for {cat}...")
                # Find our how many samples we have
                cat_df = df[df[' Label'] == cat]
                shcat = cat_df.shape
                cat_num = shcat[0].compute()

                # Get a sample if there is equal/more attack data, otherwise add everything.
                # dask only does approximate sampling, so we'll have to do some post-processing to make the numbers exactly equal.
                if cat_num > ben_num:
                    ret_df = cat_df.sample(frac = ben_num / cat_num)

                else:
                    ret_df = cat_df

                outFrame = dd.concat([outFrame, ret_df])
                #print(f"Aggregated df stats: {outFrame[' Label'].value_counts().compute()}\n")

    # Return our aggregated DataFrame
    print(f"Aggregated df stats: {outFrame[' Label'].value_counts().compute()}\n")
    print("Extraction completed.")
    return outFrame

# %%
train = extract(fileList)
test = extract(fileList2)
# Out:
# Beginning extraction...
# /01-12/DrDoS_DNS.csv
# DrDoS_DNS    5071011
# BENIGN          3402
# Name:  Label, dtype: int64
#
# Aggregated df stats: BENIGN    3402
# Name:  Label, dtype: int64
#
# /01-12/DrDoS_LDAP.csv
# DrDoS_LDAP    2179930
# BENIGN           1612
# Name:  Label, dtype: int64
#
# Aggregated df stats: BENIGN    5014
# Name:  Label, dtype: int64
#
# /01-12/DrDoS_MSSQL.csv
# DrDoS_MSSQL    4522492
# BENIGN            2006
# Name:  Label, dtype: int64
#
# Aggregated df stats: BENIGN    7020
# Name:  Label, dtype: int64
#
# /01-12/DrDoS_NetBIOS.csv
# DrDoS_NetBIOS    4093279
# BENIGN              1707
# Name:  Label, dtype: int64
#
# Aggregated df stats: BENIGN    8727
# Name:  Label, dtype: int64
#
# /01-12/DrDoS_NTP.csv
# DrDoS_NTP    1202642
# BENIGN         14365
# Name:  Label, dtype: int64
#
# Aggregated df stats: BENIGN    23092
# Name:  Label, dtype: int64
#
# /01-12/DrDoS_SNMP.csv
# DrDoS_SNMP    5159870
# BENIGN           1507
# Name:  Label, dtype: int64
#
# Aggregated df stats: BENIGN    24599
# Name:  Label, dtype: int64
#
# /01-12/DrDoS_SSDP.csv
# DrDoS_SSDP    2610611
# BENIGN            763
# Name:  Label, dtype: int64
#
# Aggregated df stats: BENIGN    25362
# Name:  Label, dtype: int64
#
# /01-12/DrDoS_UDP.csv
# DrDoS_UDP    3134645
# BENIGN          2157
# Name:  Label, dtype: int64
#
# Aggregated df stats: BENIGN    27519
# Name:  Label, dtype: int64
#
# /01-12/Syn.csv
# Syn       1582289
# BENIGN        392
# Name:  Label, dtype: int64
#
# Aggregated df stats: BENIGN    27911
# Name:  Label, dtype: int64
#
# /01-12/TFTP.csv
# TFTP      20082580
# BENIGN       25247
# Name:  Label, dtype: int64
#
# Aggregated df stats: BENIGN    53158
# Name:  Label, dtype: int64
#
# /01-12/UDPLag.csv
# UDP-lag    366461
# BENIGN       3705
# WebDDoS       439
# Name:  Label, dtype: int64
#
# Aggregated df stats: BENIGN    56863
# Name:  Label, dtype: int64
#
# Number of Benign samples aggregated: 56863
# /01-12/DrDoS_DNS.csv
# Appending data for DrDoS_DNS...
# Aggregated df stats: DrDoS_DNS    56865
# BENIGN       56863
# Name:  Label, dtype: int64
#
# /01-12/DrDoS_LDAP.csv
# Appending data for DrDoS_LDAP...
# Aggregated df stats: DrDoS_DNS     56865
# BENIGN        56863
# DrDoS_LDAP    56862
# Name:  Label, dtype: int64
#
# /01-12/DrDoS_MSSQL.csv
# Appending data for DrDoS_MSSQL...
# Aggregated df stats: DrDoS_DNS      56865
# DrDoS_MSSQL    56865
# BENIGN         56863
# DrDoS_LDAP     56862
# Name:  Label, dtype: int64
#
# /01-12/DrDoS_NetBIOS.csv
# Appending data for DrDoS_NetBIOS...
# Aggregated df stats: DrDoS_DNS        56865
# DrDoS_MSSQL      56865
# BENIGN           56863
# DrDoS_LDAP       56862
# DrDoS_NetBIOS    56861
# Name:  Label, dtype: int64
#
# /01-12/DrDoS_NTP.csv
# Appending data for DrDoS_NTP...
# Aggregated df stats: DrDoS_DNS        56865
# DrDoS_MSSQL      56865
# BENIGN           56863
# DrDoS_LDAP       56862
# DrDoS_NTP        56861
# DrDoS_NetBIOS    56861
# Name:  Label, dtype: int64
#
# /01-12/DrDoS_SNMP.csv
# Appending data for DrDoS_SNMP...
# Aggregated df stats: DrDoS_DNS        56865
# DrDoS_MSSQL      56865
# BENIGN           56863
# DrDoS_SNMP       56863
# DrDoS_LDAP       56862
# DrDoS_NTP        56861
# DrDoS_NetBIOS    56861
# Name:  Label, dtype: int64
#
# /01-12/DrDoS_SSDP.csv
# Appending data for DrDoS_SSDP...
# Aggregated df stats: DrDoS_DNS        56865
# DrDoS_MSSQL      56865
# BENIGN           56863
# DrDoS_SNMP       56863
# DrDoS_LDAP       56862
# DrDoS_SSDP       56862
# DrDoS_NTP        56861
# DrDoS_NetBIOS    56861
# Name:  Label, dtype: int64
#
# /01-12/DrDoS_UDP.csv
# Appending data for DrDoS_UDP...
# Aggregated df stats: DrDoS_UDP        56866
# DrDoS_DNS        56865
# DrDoS_MSSQL      56865
# BENIGN           56863
# DrDoS_SNMP       56863
# DrDoS_LDAP       56862
# DrDoS_SSDP       56862
# DrDoS_NTP        56861
# DrDoS_NetBIOS    56861
# Name:  Label, dtype: int64
#
# /01-12/Syn.csv
# Appending data for Syn...
# Aggregated df stats: DrDoS_UDP        56866
# DrDoS_DNS        56865
# DrDoS_MSSQL      56865
# Syn              56864
# BENIGN           56863
# DrDoS_SNMP       56863
# DrDoS_LDAP       56862
# DrDoS_SSDP       56862
# DrDoS_NTP        56861
# DrDoS_NetBIOS    56861
# Name:  Label, dtype: int64
#
# /01-12/TFTP.csv
# Appending data for TFTP...
# Aggregated df stats: DrDoS_UDP        56866
# DrDoS_DNS        56865
# DrDoS_MSSQL      56865
# Syn              56864
# BENIGN           56863
# DrDoS_SNMP       56863
# TFTP             56863
# DrDoS_LDAP       56862
# DrDoS_SSDP       56862
# DrDoS_NTP        56861
# DrDoS_NetBIOS    56861
# Name:  Label, dtype: int64
#
# /01-12/UDPLag.csv
# Appending data for WebDDoS...
# Aggregated df stats: DrDoS_UDP        56866
# DrDoS_DNS        56865
# DrDoS_MSSQL      56865
# Syn              56864
# BENIGN           56863
# DrDoS_SNMP       56863
# TFTP             56863
# DrDoS_LDAP       56862
# DrDoS_SSDP       56862
# DrDoS_NTP        56861
# DrDoS_NetBIOS    56861
# WebDDoS            439
# Name:  Label, dtype: int64
#
# Appending data for UDP-lag...
# Aggregated df stats: DrDoS_UDP        56866
# DrDoS_DNS        56865
# DrDoS_MSSQL      56865
# Syn              56864
# BENIGN           56863
# DrDoS_SNMP       56863
# TFTP             56863
# UDP-lag          56863
# DrDoS_LDAP       56862
# DrDoS_SSDP       56862
# DrDoS_NTP        56861
# DrDoS_NetBIOS    56861
# WebDDoS            439
# Name:  Label, dtype: int64
#
# Extraction completed.
# Beginning extraction...
# /03-11/LDAP.csv
# LDAP       1905191
# NetBIOS     202919
# BENIGN        5124
# Name:  Label, dtype: int64
#
# Aggregated df stats: BENIGN    5124
# Name:  Label, dtype: int64
#
# /03-11/MSSQL.csv
# MSSQL     5763061
# LDAP         9931
# BENIGN       2794
# Name:  Label, dtype: int64
#
# Aggregated df stats: BENIGN    7918
# Name:  Label, dtype: int64
#
# /03-11/NetBIOS.csv
# NetBIOS    3454578
# BENIGN        1321
# Name:  Label, dtype: int64
#
# Aggregated df stats: BENIGN    9239
# Name:  Label, dtype: int64
#
# /03-11/Portmap.csv
# Portmap    186960
# BENIGN       4734
# Name:  Label, dtype: int64
#
# Aggregated df stats: BENIGN    13973
# Name:  Label, dtype: int64
#
# /03-11/Syn.csv
# Syn       4284751
# BENIGN      35790
# Name:  Label, dtype: int64
#
# Aggregated df stats: BENIGN    49763
# Name:  Label, dtype: int64
#
# /03-11/UDP.csv
# UDP       3754680
# MSSQL       24392
# BENIGN       3134
# Name:  Label, dtype: int64
#
# Aggregated df stats: BENIGN    52897
# Name:  Label, dtype: int64
#
# /03-11/UDPLag.csv
# Syn       606749
# UDP       112475
# BENIGN      4068
# UDPLag      1873
# Name:  Label, dtype: int64
#
# Aggregated df stats: BENIGN    56965
# Name:  Label, dtype: int64
#
# Number of Benign samples aggregated: 56965
# /03-11/LDAP.csv
# Appending data for NetBIOS...
# Aggregated df stats: BENIGN     56965
# NetBIOS    56965
# Name:  Label, dtype: int64
#
# Appending data for LDAP...
# Aggregated df stats: BENIGN     56965
# LDAP       56965
# NetBIOS    56965
# Name:  Label, dtype: int64
#
# /03-11/MSSQL.csv
# Appending data for MSSQL...
# Aggregated df stats: BENIGN     56965
# LDAP       56965
# MSSQL      56965
# NetBIOS    56965
# Name:  Label, dtype: int64
#
# Appending data for LDAP...
# Aggregated df stats: LDAP       66896
# BENIGN     56965
# MSSQL      56965
# NetBIOS    56965
# Name:  Label, dtype: int64
#
# /03-11/NetBIOS.csv
# Appending data for NetBIOS...
# Aggregated df stats: NetBIOS    113929
# LDAP        66896
# BENIGN      56965
# MSSQL       56965
# Name:  Label, dtype: int64
#
# /03-11/Portmap.csv
# Appending data for Portmap...
# Aggregated df stats: NetBIOS    113929
# LDAP        66896
# BENIGN      56965
# MSSQL       56965
# Portmap     56965
# Name:  Label, dtype: int64
#
# /03-11/Syn.csv
# Appending data for Syn...
# Aggregated df stats: NetBIOS    113929
# LDAP        66896
# Syn         56966
# BENIGN      56965
# MSSQL       56965
# Portmap     56965
# Name:  Label, dtype: int64
#
# /03-11/UDP.csv
# Appending data for UDP...
# Aggregated df stats: NetBIOS    113929
# LDAP        66896
# Syn         56966
# BENIGN      56965
# MSSQL       56965
# Portmap     56965
# UDP         56963
# Name:  Label, dtype: int64
#
# Appending data for MSSQL...
# Aggregated df stats: NetBIOS    113929
# MSSQL       81357
# LDAP        66896
# Syn         56966
# BENIGN      56965
# Portmap     56965
# UDP         56963
# Name:  Label, dtype: int64
#
# /03-11/UDPLag.csv
# Appending data for UDP...
# Aggregated df stats: NetBIOS    113929
# UDP        113928
# MSSQL       81357
# LDAP        66896
# Syn         56966
# BENIGN      56965
# Portmap     56965
# Name:  Label, dtype: int64
#
# Appending data for Syn...
# Aggregated df stats: Syn        113931
# NetBIOS    113929
# UDP        113928
# MSSQL       81357
# LDAP        66896
# BENIGN      56965
# Portmap     56965
# Name:  Label, dtype: int64
#
# Appending data for UDPLag...
# Aggregated df stats: Syn        113931
# NetBIOS    113929
# UDP        113928
# MSSQL       81357
# LDAP        66896
# BENIGN      56965
# Portmap     56965
# UDPLag       1873
# Name:  Label, dtype: int64
#
# Extraction completed.

# %%
dd.to_csv(df = train, filename = "day1.csv", single_file=True)
# Out:
# ['c:\\Users\\icarus\\Documents\\school\\Fall 2022\\CSI 5388\\dataset\\day1.csv']

# %%
dd.to_csv(df = test, filename = "day2.csv", single_file=True)
# Out:
# ['c:\\Users\\icarus\\Documents\\school\\Fall 2022\\CSI 5388\\dataset\\day2.csv']

# %%
df1 = pd.read_csv("day1.csv")
df2 = pd.read_csv("day2.csv")
# Out:
# C:\Users\icarus\AppData\Local\Temp\ipykernel_16992\1521114905.py:1: DtypeWarning: Columns (86) have mixed types. Specify dtype option on import or set low_memory=False.
#   df1 = pd.read_csv("day1.csv")
# C:\Users\icarus\AppData\Local\Temp\ipykernel_16992\1521114905.py:2: DtypeWarning: Columns (86) have mixed types. Specify dtype option on import or set low_memory=False.
#   df2 = pd.read_csv("day2.csv")

# %%
print(df1[" Label"].value_counts())
print(df2[" Label"].value_counts())
# Out:
# DrDoS_UDP        56866
# DrDoS_DNS        56865
# DrDoS_MSSQL      56865
# Syn              56864
# BENIGN           56863
# DrDoS_SNMP       56863
# TFTP             56863
# UDP-lag          56863
# DrDoS_LDAP       56862
# DrDoS_SSDP       56862
# DrDoS_NetBIOS    56861
# DrDoS_NTP        56861
# WebDDoS            439
# Name:  Label, dtype: int64
# Syn        113931
# NetBIOS    113929
# UDP        113928
# MSSQL       81357
# LDAP        66896
# BENIGN      56965
# Portmap     56965
# UDPLag       1873
# Name:  Label, dtype: int64

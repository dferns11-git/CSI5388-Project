# %%
"""
Modified LSTM to work on a bigger multiclass extract and tuned it a bit.

This is the final LSTM model we ended up using.

Author: Wesley
"""
import numpy as np
import pandas as pd
import seaborn as sns
import statistics as stats
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_score, recall_score, f1_score
import io # StringIO
import keras
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout, Flatten, Conv1D, Conv2D, GlobalMaxPooling2D,GlobalMaxPooling1D, MaxPool1D, MaxPool2D
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt

import tensorflow_addons as tfa

from sklearn.preprocessing import MinMaxScaler, StandardScaler

from sklearn.metrics import classification_report

# %%
binary_train = pd.read_csv("binary_train.csv")
binary_test = pd.read_csv("binary_test.csv")

# %%
# Encode attack labels to int and save as array to be used later.

binary_train[' Label'] = binary_train[' Label'].apply(lambda l : 0 if l == 'BENIGN' else 1)
binary_test[' Label'] = binary_test[' Label'].apply(lambda l : 0 if l == 'BENIGN' else 1)

binary_labels = ["BENIGN", "ATTACK"]

# %%
y_train = binary_train[" Label"].copy()
X_train = binary_train.drop([" Label"], axis=1)

y_test = binary_test[" Label"].copy()
X_test = binary_test.drop([" Label"], axis=1)

# %%
scal = StandardScaler()
scal = scal.fit(X_train)
X_test = scal.transform(X_test)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size = 0.125, stratify=y_train, random_state=42)
X_train = scal.fit_transform(X_train)
X_val = scal.transform(X_val)

# %%
n_feat = 80
X_tr = np.reshape(X_train, (len(X_train), n_feat, 1))
X_vl = np.reshape(X_val, (len(X_val), n_feat, 1))
X_tst = np.reshape(X_test, (len(X_test), n_feat, 1))

# %%
print(X_tr.shape)
print(y_train.shape)
# Out:
# (129839, 80, 1)
# (129839,)

# %%
model = keras.Sequential()
model.add(Conv1D(filters = 512, kernel_size = 3, activation='relu', input_shape=X_tr.shape[1:3]))
model.add(MaxPool1D(pool_size=2))
model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dense(256, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(16, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

#opt = keras.optimizers.Adadelta(learning_rate=0.1)
opt = tfa.optimizers.AdaBelief(learning_rate=0.001)
#opt = tfa.optimizers.AdamW(learning_rate=0.001, weight_decay = 5e-3)
reduce_lr = keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5,
                              patience=5, min_lr=0.000001)
checkpoint_filepath = './checkpoint'
model_checkpoint_callback = keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=True,
    monitor='val_loss',
    mode='min',
    save_best_only=True)

model.compile(optimizer=opt, loss='binary_crossentropy', metrics=['binary_accuracy'])
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_5 (Conv1D)           (None, 78, 512)           2048
#
#  max_pooling1d_5 (MaxPooling  (None, 39, 512)          0
#  1D)
#
#  flatten_5 (Flatten)         (None, 19968)             0
#
#  dense_30 (Dense)            (None, 512)               10224128
#
#  dense_31 (Dense)            (None, 256)               131328
#
#  dense_32 (Dense)            (None, 128)               32896
#
#  dense_33 (Dense)            (None, 64)                8256
#
#  dense_34 (Dense)            (None, 16)                1040
#
#  dense_35 (Dense)            (None, 1)                 17
#
# =================================================================
# Total params: 10,399,713
# Trainable params: 10,399,713
# Non-trainable params: 0
# _________________________________________________________________

# %%
history=model.fit(X_tr, y_train.to_numpy(), validation_data = (X_vl, y_val.to_numpy()), batch_size=512, epochs=100, callbacks = [reduce_lr,model_checkpoint_callback])
# Out:
# Epoch 1/100
# 254/254 [==============================] - 11s 37ms/step - loss: 0.0881 - binary_accuracy: 0.9779 - val_loss: 0.0236 - val_binary_accuracy: 0.9949 - lr: 0.0010
# Epoch 2/100
# 254/254 [==============================] - 9s 35ms/step - loss: 0.0261 - binary_accuracy: 0.9934 - val_loss: 0.0280 - val_binary_accuracy: 0.9948 - lr: 0.0010
# Epoch 3/100
# 254/254 [==============================] - 9s 37ms/step - loss: 0.0236 - binary_accuracy: 0.9937 - val_loss: 0.0210 - val_binary_accuracy: 0.9946 - lr: 0.0010
# Epoch 4/100
# 254/254 [==============================] - 9s 37ms/step - loss: 0.0218 - binary_accuracy: 0.9941 - val_loss: 0.0168 - val_binary_accuracy: 0.9953 - lr: 0.0010
# Epoch 5/100
# 254/254 [==============================] - 9s 36ms/step - loss: 0.0191 - binary_accuracy: 0.9943 - val_loss: 0.0175 - val_binary_accuracy: 0.9947 - lr: 0.0010
# Epoch 6/100
# 254/254 [==============================] - 9s 36ms/step - loss: 0.0187 - binary_accuracy: 0.9943 - val_loss: 0.0188 - val_binary_accuracy: 0.9941 - lr: 0.0010
# Epoch 7/100
# 254/254 [==============================] - 9s 37ms/step - loss: 0.0167 - binary_accuracy: 0.9948 - val_loss: 0.0164 - val_binary_accuracy: 0.9956 - lr: 0.0010
# Epoch 8/100
# 254/254 [==============================] - 9s 37ms/step - loss: 0.0153 - binary_accuracy: 0.9951 - val_loss: 0.0119 - val_binary_accuracy: 0.9965 - lr: 0.0010
# Epoch 9/100
# 254/254 [==============================] - 9s 36ms/step - loss: 0.0152 - binary_accuracy: 0.9953 - val_loss: 0.0150 - val_binary_accuracy: 0.9956 - lr: 0.0010
# Epoch 10/100
# 254/254 [==============================] - 9s 36ms/step - loss: 0.0149 - binary_accuracy: 0.9952 - val_loss: 0.0161 - val_binary_accuracy: 0.9953 - lr: 0.0010
# Epoch 11/100
# 254/254 [==============================] - 9s 37ms/step - loss: 0.0127 - binary_accuracy: 0.9960 - val_loss: 0.0108 - val_binary_accuracy: 0.9968 - lr: 0.0010
# Epoch 12/100
# 254/254 [==============================] - 9s 36ms/step - loss: 0.0124 - binary_accuracy: 0.9960 - val_loss: 0.0113 - val_binary_accuracy: 0.9967 - lr: 0.0010
# Epoch 13/100
# 254/254 [==============================] - 9s 37ms/step - loss: 0.0118 - binary_accuracy: 0.9965 - val_loss: 0.0098 - val_binary_accuracy: 0.9967 - lr: 0.0010
# Epoch 14/100
# 254/254 [==============================] - 9s 36ms/step - loss: 0.0113 - binary_accuracy: 0.9966 - val_loss: 0.0142 - val_binary_accuracy: 0.9962 - lr: 0.0010
# Epoch 15/100
# 254/254 [==============================] - 9s 36ms/step - loss: 0.0108 - binary_accuracy: 0.9967 - val_loss: 0.0117 - val_binary_accuracy: 0.9965 - lr: 0.0010
# Epoch 16/100
# 254/254 [==============================] - 9s 37ms/step - loss: 0.0110 - binary_accuracy: 0.9967 - val_loss: 0.0098 - val_binary_accuracy: 0.9969 - lr: 0.0010
# Epoch 17/100
# 254/254 [==============================] - 9s 37ms/step - loss: 0.0100 - binary_accuracy: 0.9969 - val_loss: 0.0094 - val_binary_accuracy: 0.9969 - lr: 0.0010
# Epoch 18/100
# 254/254 [==============================] - 9s 36ms/step - loss: 0.0097 - binary_accuracy: 0.9970 - val_loss: 0.0097 - val_binary_accuracy: 0.9973 - lr: 0.0010
# Epoch 19/100
# 254/254 [==============================] - 9s 36ms/step - loss: 0.0114 - binary_accuracy: 0.9966 - val_loss: 0.0095 - val_binary_accuracy: 0.9972 - lr: 0.0010
# Epoch 20/100
# 254/254 [==============================] - 9s 36ms/step - loss: 0.0096 - binary_accuracy: 0.9970 - val_loss: 0.0096 - val_binary_accuracy: 0.9971 - lr: 0.0010
# Epoch 21/100
# 254/254 [==============================] - 9s 36ms/step - loss: 0.0096 - binary_accuracy: 0.9971 - val_loss: 0.0106 - val_binary_accuracy: 0.9970 - lr: 0.0010
# Epoch 22/100
# 254/254 [==============================] - 9s 36ms/step - loss: 0.0091 - binary_accuracy: 0.9972 - val_loss: 0.0101 - val_binary_accuracy: 0.9971 - lr: 0.0010
# Epoch 23/100
# 254/254 [==============================] - 9s 37ms/step - loss: 0.0071 - binary_accuracy: 0.9977 - val_loss: 0.0087 - val_binary_accuracy: 0.9976 - lr: 5.0000e-04
# Epoch 24/100
# 254/254 [==============================] - 9s 36ms/step - loss: 0.0072 - binary_accuracy: 0.9976 - val_loss: 0.0090 - val_binary_accuracy: 0.9974 - lr: 5.0000e-04
# Epoch 25/100
# 254/254 [==============================] - 9s 36ms/step - loss: 0.0068 - binary_accuracy: 0.9978 - val_loss: 0.0083 - val_binary_accuracy: 0.9977 - lr: 5.0000e-04
# Epoch 26/100
# 254/254 [==============================] - 9s 35ms/step - loss: 0.0065 - binary_accuracy: 0.9979 - val_loss: 0.0084 - val_binary_accuracy: 0.9978 - lr: 5.0000e-04
# Epoch 27/100
# 254/254 [==============================] - 9s 35ms/step - loss: 0.0065 - binary_accuracy: 0.9978 - val_loss: 0.0138 - val_binary_accuracy: 0.9958 - lr: 5.0000e-04
# Epoch 28/100
# 254/254 [==============================] - 9s 35ms/step - loss: 0.0068 - binary_accuracy: 0.9978 - val_loss: 0.0086 - val_binary_accuracy: 0.9973 - lr: 5.0000e-04
# Epoch 29/100
# 254/254 [==============================] - 9s 37ms/step - loss: 0.0065 - binary_accuracy: 0.9979 - val_loss: 0.0079 - val_binary_accuracy: 0.9982 - lr: 5.0000e-04
# Epoch 30/100
# 254/254 [==============================] - 9s 35ms/step - loss: 0.0065 - binary_accuracy: 0.9979 - val_loss: 0.0082 - val_binary_accuracy: 0.9979 - lr: 5.0000e-04
# Epoch 31/100
# 254/254 [==============================] - 9s 37ms/step - loss: 0.0063 - binary_accuracy: 0.9980 - val_loss: 0.0075 - val_binary_accuracy: 0.9979 - lr: 5.0000e-04
# Epoch 32/100
# 254/254 [==============================] - 9s 35ms/step - loss: 0.0060 - binary_accuracy: 0.9981 - val_loss: 0.0076 - val_binary_accuracy: 0.9979 - lr: 5.0000e-04
# Epoch 33/100
# 254/254 [==============================] - 9s 35ms/step - loss: 0.0060 - binary_accuracy: 0.9980 - val_loss: 0.0076 - val_binary_accuracy: 0.9980 - lr: 5.0000e-04
# Epoch 34/100
# 254/254 [==============================] - 9s 36ms/step - loss: 0.0060 - binary_accuracy: 0.9982 - val_loss: 0.0074 - val_binary_accuracy: 0.9978 - lr: 5.0000e-04
# Epoch 35/100
# 254/254 [==============================] - 9s 37ms/step - loss: 0.0062 - binary_accuracy: 0.9981 - val_loss: 0.0074 - val_binary_accuracy: 0.9980 - lr: 5.0000e-04
# Epoch 36/100
# 254/254 [==============================] - 9s 35ms/step - loss: 0.0057 - binary_accuracy: 0.9982 - val_loss: 0.0075 - val_binary_accuracy: 0.9980 - lr: 5.0000e-04
# Epoch 37/100
# 254/254 [==============================] - 9s 35ms/step - loss: 0.0058 - binary_accuracy: 0.9981 - val_loss: 0.0075 - val_binary_accuracy: 0.9974 - lr: 5.0000e-04
# Epoch 38/100
# 254/254 [==============================] - 9s 36ms/step - loss: 0.0055 - binary_accuracy: 0.9981 - val_loss: 0.0075 - val_binary_accuracy: 0.9977 - lr: 5.0000e-04
# Epoch 39/100
# 254/254 [==============================] - 9s 36ms/step - loss: 0.0053 - binary_accuracy: 0.9983 - val_loss: 0.0075 - val_binary_accuracy: 0.9984 - lr: 5.0000e-04
# Epoch 40/100
# 254/254 [==============================] - 9s 36ms/step - loss: 0.0053 - binary_accuracy: 0.9983 - val_loss: 0.0089 - val_binary_accuracy: 0.9978 - lr: 5.0000e-04
# Epoch 41/100
# 254/254 [==============================] - 9s 35ms/step - loss: 0.0046 - binary_accuracy: 0.9985 - val_loss: 0.0084 - val_binary_accuracy: 0.9982 - lr: 2.5000e-04
# Epoch 42/100
# 254/254 [==============================] - 9s 37ms/step - loss: 0.0046 - binary_accuracy: 0.9985 - val_loss: 0.0073 - val_binary_accuracy: 0.9983 - lr: 2.5000e-04
# Epoch 43/100
# 254/254 [==============================] - 9s 35ms/step - loss: 0.0044 - binary_accuracy: 0.9985 - val_loss: 0.0076 - val_binary_accuracy: 0.9985 - lr: 2.5000e-04
# Epoch 44/100
# 254/254 [==============================] - 9s 37ms/step - loss: 0.0044 - binary_accuracy: 0.9986 - val_loss: 0.0072 - val_binary_accuracy: 0.9983 - lr: 2.5000e-04
# Epoch 45/100
# 254/254 [==============================] - 9s 37ms/step - loss: 0.0042 - binary_accuracy: 0.9986 - val_loss: 0.0068 - val_binary_accuracy: 0.9984 - lr: 2.5000e-04
# Epoch 46/100
# 254/254 [==============================] - 9s 35ms/step - loss: 0.0043 - binary_accuracy: 0.9986 - val_loss: 0.0074 - val_binary_accuracy: 0.9983 - lr: 2.5000e-04
# Epoch 47/100
# 254/254 [==============================] - 9s 35ms/step - loss: 0.0043 - binary_accuracy: 0.9986 - val_loss: 0.0072 - val_binary_accuracy: 0.9985 - lr: 2.5000e-04
# Epoch 48/100
# 254/254 [==============================] - 9s 35ms/step - loss: 0.0042 - binary_accuracy: 0.9986 - val_loss: 0.0079 - val_binary_accuracy: 0.9982 - lr: 2.5000e-04
# Epoch 49/100
# 254/254 [==============================] - 9s 35ms/step - loss: 0.0041 - binary_accuracy: 0.9987 - val_loss: 0.0073 - val_binary_accuracy: 0.9982 - lr: 2.5000e-04
# Epoch 50/100
# 254/254 [==============================] - 9s 35ms/step - loss: 0.0039 - binary_accuracy: 0.9987 - val_loss: 0.0080 - val_binary_accuracy: 0.9983 - lr: 2.5000e-04
# Epoch 51/100
# 254/254 [==============================] - 9s 35ms/step - loss: 0.0037 - binary_accuracy: 0.9988 - val_loss: 0.0076 - val_binary_accuracy: 0.9983 - lr: 1.2500e-04
# Epoch 52/100
# 254/254 [==============================] - 9s 35ms/step - loss: 0.0037 - binary_accuracy: 0.9988 - val_loss: 0.0076 - val_binary_accuracy: 0.9983 - lr: 1.2500e-04
# Epoch 53/100
# 254/254 [==============================] - 9s 35ms/step - loss: 0.0036 - binary_accuracy: 0.9988 - val_loss: 0.0072 - val_binary_accuracy: 0.9985 - lr: 1.2500e-04
# Epoch 54/100
# 254/254 [==============================] - 9s 35ms/step - loss: 0.0036 - binary_accuracy: 0.9988 - val_loss: 0.0075 - val_binary_accuracy: 0.9985 - lr: 1.2500e-04
# Epoch 55/100
# 254/254 [==============================] - 9s 35ms/step - loss: 0.0035 - binary_accuracy: 0.9989 - val_loss: 0.0078 - val_binary_accuracy: 0.9984 - lr: 1.2500e-04
# Epoch 56/100
# 254/254 [==============================] - 9s 35ms/step - loss: 0.0033 - binary_accuracy: 0.9989 - val_loss: 0.0077 - val_binary_accuracy: 0.9985 - lr: 6.2500e-05
# Epoch 57/100
# 254/254 [==============================] - 9s 35ms/step - loss: 0.0032 - binary_accuracy: 0.9989 - val_loss: 0.0077 - val_binary_accuracy: 0.9986 - lr: 6.2500e-05
# Epoch 58/100
# 254/254 [==============================] - 9s 35ms/step - loss: 0.0032 - binary_accuracy: 0.9989 - val_loss: 0.0072 - val_binary_accuracy: 0.9988 - lr: 6.2500e-05
# Epoch 59/100
# 254/254 [==============================] - 9s 35ms/step - loss: 0.0031 - binary_accuracy: 0.9990 - val_loss: 0.0079 - val_binary_accuracy: 0.9984 - lr: 6.2500e-05
# Epoch 60/100
# 254/254 [==============================] - 9s 36ms/step - loss: 0.0031 - binary_accuracy: 0.9989 - val_loss: 0.0076 - val_binary_accuracy: 0.9987 - lr: 6.2500e-05
# Epoch 61/100
# 254/254 [==============================] - 9s 35ms/step - loss: 0.0030 - binary_accuracy: 0.9990 - val_loss: 0.0077 - val_binary_accuracy: 0.9987 - lr: 3.1250e-05
# Epoch 62/100
# 254/254 [==============================] - 9s 35ms/step - loss: 0.0029 - binary_accuracy: 0.9990 - val_loss: 0.0078 - val_binary_accuracy: 0.9988 - lr: 3.1250e-05
# Epoch 63/100
# 254/254 [==============================] - 9s 36ms/step - loss: 0.0029 - binary_accuracy: 0.9990 - val_loss: 0.0075 - val_binary_accuracy: 0.9987 - lr: 3.1250e-05
# Epoch 64/100
# 254/254 [==============================] - 9s 35ms/step - loss: 0.0029 - binary_accuracy: 0.9990 - val_loss: 0.0078 - val_binary_accuracy: 0.9984 - lr: 3.1250e-05
# Epoch 65/100
# 254/254 [==============================] - 9s 35ms/step - loss: 0.0029 - binary_accuracy: 0.9991 - val_loss: 0.0079 - val_binary_accuracy: 0.9987 - lr: 3.1250e-05
# Epoch 66/100
# 254/254 [==============================] - 9s 35ms/step - loss: 0.0028 - binary_accuracy: 0.9991 - val_loss: 0.0080 - val_binary_accuracy: 0.9985 - lr: 1.5625e-05
# Epoch 67/100
# 254/254 [==============================] - 9s 35ms/step - loss: 0.0028 - binary_accuracy: 0.9991 - val_loss: 0.0079 - val_binary_accuracy: 0.9987 - lr: 1.5625e-05
# Epoch 68/100
# 254/254 [==============================] - 9s 35ms/step - loss: 0.0028 - binary_accuracy: 0.9991 - val_loss: 0.0080 - val_binary_accuracy: 0.9987 - lr: 1.5625e-05
# Epoch 69/100
# 254/254 [==============================] - 9s 35ms/step - loss: 0.0028 - binary_accuracy: 0.9991 - val_loss: 0.0079 - val_binary_accuracy: 0.9987 - lr: 1.5625e-05
# Epoch 70/100
# 254/254 [==============================] - 9s 35ms/step - loss: 0.0028 - binary_accuracy: 0.9991 - val_loss: 0.0080 - val_binary_accuracy: 0.9987 - lr: 1.5625e-05
# Epoch 71/100
# 254/254 [==============================] - 9s 35ms/step - loss: 0.0027 - binary_accuracy: 0.9991 - val_loss: 0.0080 - val_binary_accuracy: 0.9984 - lr: 7.8125e-06
# Epoch 72/100
# 254/254 [==============================] - 9s 35ms/step - loss: 0.0027 - binary_accuracy: 0.9991 - val_loss: 0.0079 - val_binary_accuracy: 0.9986 - lr: 7.8125e-06
# Epoch 73/100
# 254/254 [==============================] - 9s 35ms/step - loss: 0.0027 - binary_accuracy: 0.9991 - val_loss: 0.0080 - val_binary_accuracy: 0.9984 - lr: 7.8125e-06
# Epoch 74/100
# 254/254 [==============================] - 9s 35ms/step - loss: 0.0027 - binary_accuracy: 0.9991 - val_loss: 0.0080 - val_binary_accuracy: 0.9986 - lr: 7.8125e-06
# Epoch 75/100
# 254/254 [==============================] - 9s 35ms/step - loss: 0.0027 - binary_accuracy: 0.9991 - val_loss: 0.0080 - val_binary_accuracy: 0.9985 - lr: 7.8125e-06
# Epoch 76/100
# 254/254 [==============================] - 9s 35ms/step - loss: 0.0027 - binary_accuracy: 0.9992 - val_loss: 0.0080 - val_binary_accuracy: 0.9985 - lr: 3.9063e-06
# Epoch 77/100
# 254/254 [==============================] - 9s 36ms/step - loss: 0.0027 - binary_accuracy: 0.9992 - val_loss: 0.0080 - val_binary_accuracy: 0.9985 - lr: 3.9063e-06
# Epoch 78/100
# 254/254 [==============================] - 9s 35ms/step - loss: 0.0027 - binary_accuracy: 0.9991 - val_loss: 0.0081 - val_binary_accuracy: 0.9985 - lr: 3.9063e-06
# Epoch 79/100
# 254/254 [==============================] - 9s 36ms/step - loss: 0.0027 - binary_accuracy: 0.9991 - val_loss: 0.0080 - val_binary_accuracy: 0.9986 - lr: 3.9063e-06
# Epoch 80/100
# 254/254 [==============================] - 9s 35ms/step - loss: 0.0027 - binary_accuracy: 0.9991 - val_loss: 0.0080 - val_binary_accuracy: 0.9985 - lr: 3.9063e-06
# Epoch 81/100
# 254/254 [==============================] - 9s 35ms/step - loss: 0.0027 - binary_accuracy: 0.9992 - val_loss: 0.0081 - val_binary_accuracy: 0.9985 - lr: 1.9531e-06
# Epoch 82/100
# 254/254 [==============================] - 9s 35ms/step - loss: 0.0027 - binary_accuracy: 0.9992 - val_loss: 0.0081 - val_binary_accuracy: 0.9985 - lr: 1.9531e-06
# Epoch 83/100
# 254/254 [==============================] - 9s 35ms/step - loss: 0.0027 - binary_accuracy: 0.9992 - val_loss: 0.0081 - val_binary_accuracy: 0.9986 - lr: 1.9531e-06
# Epoch 84/100
# 254/254 [==============================] - 9s 36ms/step - loss: 0.0027 - binary_accuracy: 0.9991 - val_loss: 0.0081 - val_binary_accuracy: 0.9985 - lr: 1.9531e-06
# Epoch 85/100
# 254/254 [==============================] - 9s 35ms/step - loss: 0.0027 - binary_accuracy: 0.9992 - val_loss: 0.0081 - val_binary_accuracy: 0.9985 - lr: 1.9531e-06
# Epoch 86/100
# 254/254 [==============================] - 9s 35ms/step - loss: 0.0027 - binary_accuracy: 0.9992 - val_loss: 0.0081 - val_binary_accuracy: 0.9985 - lr: 1.0000e-06
# Epoch 87/100
# 254/254 [==============================] - 9s 36ms/step - loss: 0.0027 - binary_accuracy: 0.9992 - val_loss: 0.0081 - val_binary_accuracy: 0.9985 - lr: 1.0000e-06
# Epoch 88/100
# 254/254 [==============================] - 9s 35ms/step - loss: 0.0027 - binary_accuracy: 0.9992 - val_loss: 0.0081 - val_binary_accuracy: 0.9985 - lr: 1.0000e-06
# Epoch 89/100
# 254/254 [==============================] - 9s 35ms/step - loss: 0.0027 - binary_accuracy: 0.9992 - val_loss: 0.0081 - val_binary_accuracy: 0.9985 - lr: 1.0000e-06
# Epoch 90/100
# 254/254 [==============================] - 9s 35ms/step - loss: 0.0027 - binary_accuracy: 0.9992 - val_loss: 0.0081 - val_binary_accuracy: 0.9985 - lr: 1.0000e-06
# Epoch 91/100
# 254/254 [==============================] - 9s 35ms/step - loss: 0.0027 - binary_accuracy: 0.9992 - val_loss: 0.0081 - val_binary_accuracy: 0.9985 - lr: 1.0000e-06
# Epoch 92/100
# 254/254 [==============================] - 9s 35ms/step - loss: 0.0027 - binary_accuracy: 0.9992 - val_loss: 0.0081 - val_binary_accuracy: 0.9985 - lr: 1.0000e-06
# Epoch 93/100
# 254/254 [==============================] - 9s 34ms/step - loss: 0.0027 - binary_accuracy: 0.9992 - val_loss: 0.0081 - val_binary_accuracy: 0.9985 - lr: 1.0000e-06
# Epoch 94/100
# 254/254 [==============================] - 9s 34ms/step - loss: 0.0027 - binary_accuracy: 0.9992 - val_loss: 0.0081 - val_binary_accuracy: 0.9985 - lr: 1.0000e-06
# Epoch 95/100
# 254/254 [==============================] - 9s 34ms/step - loss: 0.0027 - binary_accuracy: 0.9992 - val_loss: 0.0081 - val_binary_accuracy: 0.9985 - lr: 1.0000e-06
# Epoch 96/100
# 254/254 [==============================] - 9s 34ms/step - loss: 0.0027 - binary_accuracy: 0.9992 - val_loss: 0.0081 - val_binary_accuracy: 0.9985 - lr: 1.0000e-06
# Epoch 97/100
# 254/254 [==============================] - 9s 34ms/step - loss: 0.0027 - binary_accuracy: 0.9992 - val_loss: 0.0081 - val_binary_accuracy: 0.9985 - lr: 1.0000e-06
# Epoch 98/100
# 254/254 [==============================] - 9s 34ms/step - loss: 0.0026 - binary_accuracy: 0.9992 - val_loss: 0.0081 - val_binary_accuracy: 0.9985 - lr: 1.0000e-06
# Epoch 99/100
# 254/254 [==============================] - 9s 34ms/step - loss: 0.0026 - binary_accuracy: 0.9992 - val_loss: 0.0081 - val_binary_accuracy: 0.9985 - lr: 1.0000e-06
# Epoch 100/100
# 254/254 [==============================] - 9s 34ms/step - loss: 0.0026 - binary_accuracy: 0.9992 - val_loss: 0.0081 - val_binary_accuracy: 0.9985 - lr: 1.0000e-06

# %%
#history=model.fit(X_tr, y_train.to_numpy(), batch_size=len(X_tr), epochs=10)
path_new_model = "CNN_binary_final.h5"

#Save final model
model.save(path_new_model)

# %%
# list all data in history
print(history.history.keys())
# summarize history for accuracy
plt.plot(history.history['binary_accuracy'])
plt.plot(history.history['binary_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'binary_accuracy', 'val_loss', 'val_binary_accuracy', 'lr'])

# %%
#Test predictions
#model.load_weights(checkpoint_filepath)
prediction = model.predict(X_tst)
# Out:
# 1160/1160 [==============================] - 4s 3ms/step

# %%
pred = [1 if prediction[i] >= 0.5 else 0 for i in range(len(prediction))]
#pred = [np.argmax(x) for x in prediction]
pd.Series(pred).value_counts()
# Out:
# 0    18577
# 1    18521
# dtype: int64

# %%
print(classification_report(y_test.to_numpy(), pred, digits=6,target_names=binary_labels))
# Out:
#               precision    recall  f1-score   support
#
#       BENIGN   0.997901  0.999461  0.998680     18548
#       ATTACK   0.999460  0.997898  0.998678     18550
#
#     accuracy                       0.998679     37098
#    macro avg   0.998680  0.998679  0.998679     37098
# weighted avg   0.998680  0.998679  0.998679     37098

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

cm = confusion_matrix(y_test, pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=binary_labels)
fig, ax = plt.subplots(figsize=(12,12))
disp.plot(ax=ax)
plt.savefig("confusion_binary_cnn.png")

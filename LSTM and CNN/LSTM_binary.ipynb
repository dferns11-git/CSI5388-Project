# %%
"""
Modified LSTM to work on a bigger multiclass extract and tuned it a bit.

This is the final LSTM model we ended up using.

Author: Wesley
"""
import numpy as np
import pandas as pd
import seaborn as sns
import statistics as stats
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_score, recall_score, f1_score
import io # StringIO
import keras
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout, Flatten
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt

import tensorflow_addons as tfa

from sklearn.preprocessing import MinMaxScaler, StandardScaler

from sklearn.metrics import classification_report

# %%
binary_train = pd.read_csv("binary_train.csv")
binary_test = pd.read_csv("binary_test.csv")

# %%
# Encode attack labels to int and save as array to be used later.

binary_train[' Label'] = binary_train[' Label'].apply(lambda l : 0 if l == 'BENIGN' else 1)
binary_test[' Label'] = binary_test[' Label'].apply(lambda l : 0 if l == 'BENIGN' else 1)

binary_labels = ["BENIGN", "ATTACK"]

# %%
y_train = binary_train[" Label"].copy()
X_train = binary_train.drop([" Label"], axis=1)

y_test = binary_test[" Label"].copy()
X_test = binary_test.drop([" Label"], axis=1)

# %%
scal = StandardScaler()
scal = scal.fit(X_train)
X_test = scal.transform(X_test)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size = 0.125, stratify=y_train, random_state=42)
X_train = scal.fit_transform(X_train)
X_val = scal.transform(X_val)

# %%
n_feat = 80
X_tr = np.reshape(X_train, (len(X_train), 1, n_feat))
X_vl = np.reshape(X_val, (len(X_val), 1, n_feat))
X_tst = np.reshape(X_test, (len(X_test), 1, n_feat))

# %%
print(X_tr.shape)
print(y_train.shape)
# Out:
# (129839, 1, 80)
# (129839,)

# %%
model = keras.Sequential()
model.add(keras.Input(shape=(1, n_feat)))
model.add(LSTM(512, activation=tfa.activations.gelu, return_sequences=True))
model.add(Flatten())
model.add(Dense(256, activation=tfa.activations.gelu))
model.add(Dense(64, activation=tfa.activations.gelu))
model.add(Dense(32, activation=tfa.activations.gelu))
model.add(Dense(8, activation=tfa.activations.gelu))
model.add(Dense(1, activation='sigmoid'))

opt = keras.optimizers.Adam(learning_rate=0.001)
reduce_lr = keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5,
                              patience=5, min_lr=0.000001)
checkpoint_filepath = './checkpoint'
model_checkpoint_callback = keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=True,
    monitor='val_loss',
    mode='min',
    save_best_only=True)

model.compile(optimizer=opt, loss='binary_crossentropy', metrics=['binary_accuracy'])
model.summary()
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 1, 512)            1214464
#
#  flatten (Flatten)           (None, 512)               0
#
#  dense (Dense)               (None, 256)               131328
#
#  dense_1 (Dense)             (None, 64)                16448
#
#  dense_2 (Dense)             (None, 32)                2080
#
#  dense_3 (Dense)             (None, 8)                 264
#
#  dense_4 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 1,364,593
# Trainable params: 1,364,593
# Non-trainable params: 0
# _________________________________________________________________

# %%
history=model.fit(X_tr, y_train.to_numpy(), validation_data = (X_vl, y_val.to_numpy()), batch_size=512, epochs=50, callbacks = [reduce_lr,model_checkpoint_callback])
# Out:
# Epoch 1/50
# 254/254 [==============================] - 6s 14ms/step - loss: 0.0775 - binary_accuracy: 0.9800 - val_loss: 0.0205 - val_binary_accuracy: 0.9953 - lr: 0.0010
# Epoch 2/50
# 254/254 [==============================] - 3s 12ms/step - loss: 0.0226 - binary_accuracy: 0.9944 - val_loss: 0.0194 - val_binary_accuracy: 0.9954 - lr: 0.0010
# Epoch 3/50
# 254/254 [==============================] - 3s 12ms/step - loss: 0.0215 - binary_accuracy: 0.9944 - val_loss: 0.0175 - val_binary_accuracy: 0.9957 - lr: 0.0010
# Epoch 4/50
# 254/254 [==============================] - 3s 12ms/step - loss: 0.0197 - binary_accuracy: 0.9948 - val_loss: 0.0168 - val_binary_accuracy: 0.9953 - lr: 0.0010
# Epoch 5/50
# 254/254 [==============================] - 3s 12ms/step - loss: 0.0175 - binary_accuracy: 0.9952 - val_loss: 0.0171 - val_binary_accuracy: 0.9958 - lr: 0.0010
# Epoch 6/50
# 254/254 [==============================] - 3s 12ms/step - loss: 0.0166 - binary_accuracy: 0.9955 - val_loss: 0.0175 - val_binary_accuracy: 0.9962 - lr: 0.0010
# Epoch 7/50
# 254/254 [==============================] - 3s 12ms/step - loss: 0.0161 - binary_accuracy: 0.9955 - val_loss: 0.0191 - val_binary_accuracy: 0.9950 - lr: 0.0010
# Epoch 8/50
# 254/254 [==============================] - 3s 12ms/step - loss: 0.0153 - binary_accuracy: 0.9956 - val_loss: 0.0215 - val_binary_accuracy: 0.9957 - lr: 0.0010
# Epoch 9/50
# 254/254 [==============================] - 3s 12ms/step - loss: 0.0149 - binary_accuracy: 0.9955 - val_loss: 0.0137 - val_binary_accuracy: 0.9960 - lr: 0.0010
# Epoch 10/50
# 254/254 [==============================] - 3s 12ms/step - loss: 0.0160 - binary_accuracy: 0.9954 - val_loss: 0.0144 - val_binary_accuracy: 0.9960 - lr: 0.0010
# Epoch 11/50
# 254/254 [==============================] - 3s 12ms/step - loss: 0.0152 - binary_accuracy: 0.9952 - val_loss: 0.0146 - val_binary_accuracy: 0.9959 - lr: 0.0010
# Epoch 12/50
# 254/254 [==============================] - 3s 12ms/step - loss: 0.0146 - binary_accuracy: 0.9956 - val_loss: 0.0160 - val_binary_accuracy: 0.9962 - lr: 0.0010
# Epoch 13/50
# 254/254 [==============================] - 3s 12ms/step - loss: 0.0139 - binary_accuracy: 0.9959 - val_loss: 0.0158 - val_binary_accuracy: 0.9961 - lr: 0.0010
# Epoch 14/50
# 254/254 [==============================] - 3s 12ms/step - loss: 0.0127 - binary_accuracy: 0.9961 - val_loss: 0.0145 - val_binary_accuracy: 0.9964 - lr: 0.0010
# Epoch 15/50
# 254/254 [==============================] - 3s 12ms/step - loss: 0.0113 - binary_accuracy: 0.9963 - val_loss: 0.0147 - val_binary_accuracy: 0.9961 - lr: 5.0000e-04
# Epoch 16/50
# 254/254 [==============================] - 3s 12ms/step - loss: 0.0109 - binary_accuracy: 0.9965 - val_loss: 0.0208 - val_binary_accuracy: 0.9930 - lr: 5.0000e-04
# Epoch 17/50
# 254/254 [==============================] - 3s 12ms/step - loss: 0.0106 - binary_accuracy: 0.9965 - val_loss: 0.0156 - val_binary_accuracy: 0.9949 - lr: 5.0000e-04
# Epoch 18/50
# 254/254 [==============================] - 3s 12ms/step - loss: 0.0102 - binary_accuracy: 0.9965 - val_loss: 0.0140 - val_binary_accuracy: 0.9973 - lr: 5.0000e-04
# Epoch 19/50
# 254/254 [==============================] - 3s 12ms/step - loss: 0.0095 - binary_accuracy: 0.9968 - val_loss: 0.0141 - val_binary_accuracy: 0.9971 - lr: 5.0000e-04
# Epoch 20/50
# 254/254 [==============================] - 3s 12ms/step - loss: 0.0090 - binary_accuracy: 0.9971 - val_loss: 0.0145 - val_binary_accuracy: 0.9975 - lr: 2.5000e-04
# Epoch 21/50
# 254/254 [==============================] - 3s 12ms/step - loss: 0.0085 - binary_accuracy: 0.9972 - val_loss: 0.0144 - val_binary_accuracy: 0.9974 - lr: 2.5000e-04
# Epoch 22/50
# 254/254 [==============================] - 3s 12ms/step - loss: 0.0084 - binary_accuracy: 0.9972 - val_loss: 0.0141 - val_binary_accuracy: 0.9975 - lr: 2.5000e-04
# Epoch 23/50
# 254/254 [==============================] - 3s 12ms/step - loss: 0.0085 - binary_accuracy: 0.9971 - val_loss: 0.0144 - val_binary_accuracy: 0.9971 - lr: 2.5000e-04
# Epoch 24/50
# 254/254 [==============================] - 3s 12ms/step - loss: 0.0081 - binary_accuracy: 0.9974 - val_loss: 0.0145 - val_binary_accuracy: 0.9971 - lr: 2.5000e-04
# Epoch 25/50
# 254/254 [==============================] - 3s 12ms/step - loss: 0.0078 - binary_accuracy: 0.9973 - val_loss: 0.0146 - val_binary_accuracy: 0.9971 - lr: 1.2500e-04
# Epoch 26/50
# 254/254 [==============================] - 3s 12ms/step - loss: 0.0077 - binary_accuracy: 0.9974 - val_loss: 0.0144 - val_binary_accuracy: 0.9974 - lr: 1.2500e-04
# Epoch 27/50
# 254/254 [==============================] - 3s 12ms/step - loss: 0.0077 - binary_accuracy: 0.9974 - val_loss: 0.0142 - val_binary_accuracy: 0.9975 - lr: 1.2500e-04
# Epoch 28/50
# 254/254 [==============================] - 3s 12ms/step - loss: 0.0076 - binary_accuracy: 0.9975 - val_loss: 0.0140 - val_binary_accuracy: 0.9976 - lr: 1.2500e-04
# Epoch 29/50
# 254/254 [==============================] - 3s 12ms/step - loss: 0.0076 - binary_accuracy: 0.9974 - val_loss: 0.0139 - val_binary_accuracy: 0.9977 - lr: 1.2500e-04
# Epoch 30/50
# 254/254 [==============================] - 3s 12ms/step - loss: 0.0073 - binary_accuracy: 0.9975 - val_loss: 0.0141 - val_binary_accuracy: 0.9975 - lr: 6.2500e-05
# Epoch 31/50
# 254/254 [==============================] - 3s 12ms/step - loss: 0.0073 - binary_accuracy: 0.9976 - val_loss: 0.0141 - val_binary_accuracy: 0.9976 - lr: 6.2500e-05
# Epoch 32/50
# 254/254 [==============================] - 3s 12ms/step - loss: 0.0072 - binary_accuracy: 0.9975 - val_loss: 0.0141 - val_binary_accuracy: 0.9976 - lr: 6.2500e-05
# Epoch 33/50
# 254/254 [==============================] - 3s 12ms/step - loss: 0.0071 - binary_accuracy: 0.9976 - val_loss: 0.0141 - val_binary_accuracy: 0.9976 - lr: 6.2500e-05
# Epoch 34/50
# 254/254 [==============================] - 3s 12ms/step - loss: 0.0072 - binary_accuracy: 0.9976 - val_loss: 0.0144 - val_binary_accuracy: 0.9976 - lr: 6.2500e-05
# Epoch 35/50
# 254/254 [==============================] - 3s 12ms/step - loss: 0.0071 - binary_accuracy: 0.9976 - val_loss: 0.0141 - val_binary_accuracy: 0.9977 - lr: 3.1250e-05
# Epoch 36/50
# 254/254 [==============================] - 3s 12ms/step - loss: 0.0070 - binary_accuracy: 0.9976 - val_loss: 0.0143 - val_binary_accuracy: 0.9976 - lr: 3.1250e-05
# Epoch 37/50
# 254/254 [==============================] - 3s 12ms/step - loss: 0.0071 - binary_accuracy: 0.9976 - val_loss: 0.0141 - val_binary_accuracy: 0.9977 - lr: 3.1250e-05
# Epoch 38/50
# 254/254 [==============================] - 3s 12ms/step - loss: 0.0070 - binary_accuracy: 0.9976 - val_loss: 0.0141 - val_binary_accuracy: 0.9977 - lr: 3.1250e-05
# Epoch 39/50
# 254/254 [==============================] - 3s 12ms/step - loss: 0.0070 - binary_accuracy: 0.9976 - val_loss: 0.0142 - val_binary_accuracy: 0.9977 - lr: 3.1250e-05
# Epoch 40/50
# 254/254 [==============================] - 3s 12ms/step - loss: 0.0069 - binary_accuracy: 0.9976 - val_loss: 0.0142 - val_binary_accuracy: 0.9977 - lr: 1.5625e-05
# Epoch 41/50
# 254/254 [==============================] - 3s 12ms/step - loss: 0.0069 - binary_accuracy: 0.9976 - val_loss: 0.0141 - val_binary_accuracy: 0.9977 - lr: 1.5625e-05
# Epoch 42/50
# 254/254 [==============================] - 3s 12ms/step - loss: 0.0069 - binary_accuracy: 0.9977 - val_loss: 0.0141 - val_binary_accuracy: 0.9977 - lr: 1.5625e-05
# Epoch 43/50
# 254/254 [==============================] - 3s 12ms/step - loss: 0.0069 - binary_accuracy: 0.9976 - val_loss: 0.0142 - val_binary_accuracy: 0.9977 - lr: 1.5625e-05
# Epoch 44/50
# 254/254 [==============================] - 3s 12ms/step - loss: 0.0069 - binary_accuracy: 0.9977 - val_loss: 0.0142 - val_binary_accuracy: 0.9977 - lr: 1.5625e-05
# Epoch 45/50
# 254/254 [==============================] - 3s 12ms/step - loss: 0.0069 - binary_accuracy: 0.9977 - val_loss: 0.0141 - val_binary_accuracy: 0.9977 - lr: 7.8125e-06
# Epoch 46/50
# 254/254 [==============================] - 3s 12ms/step - loss: 0.0069 - binary_accuracy: 0.9976 - val_loss: 0.0142 - val_binary_accuracy: 0.9977 - lr: 7.8125e-06
# Epoch 47/50
# 254/254 [==============================] - 3s 12ms/step - loss: 0.0069 - binary_accuracy: 0.9977 - val_loss: 0.0142 - val_binary_accuracy: 0.9977 - lr: 7.8125e-06
# Epoch 48/50
# 254/254 [==============================] - 3s 12ms/step - loss: 0.0069 - binary_accuracy: 0.9976 - val_loss: 0.0142 - val_binary_accuracy: 0.9977 - lr: 7.8125e-06
# Epoch 49/50
# 254/254 [==============================] - 3s 12ms/step - loss: 0.0069 - binary_accuracy: 0.9976 - val_loss: 0.0142 - val_binary_accuracy: 0.9977 - lr: 7.8125e-06
# Epoch 50/50
# 254/254 [==============================] - 3s 12ms/step - loss: 0.0068 - binary_accuracy: 0.9976 - val_loss: 0.0142 - val_binary_accuracy: 0.9977 - lr: 3.9063e-06

# %%
path_new_model = "LSTM_binary_final.h5"

#Save final model
model.save(path_new_model)

# %%
# list all data in history
print(history.history.keys())
# summarize history for accuracy
plt.plot(history.history['binary_accuracy'])
plt.plot(history.history['val_binary_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'binary_accuracy', 'val_loss', 'val_binary_accuracy', 'lr'])

# %%
#Test predictions
#model.load_weights(checkpoint_filepath)
prediction = model.predict(X_tst)
# Out:
# 1160/1160 [==============================] - 3s 2ms/step

# %%
pred = [1 if prediction[i] >= 0.5 else 0 for i in range(len(prediction))]
pd.Series(pred).value_counts()
# Out:
# 0    18587
# 1    18511
# dtype: int64

# %%
print(classification_report(y_test.to_numpy(), pred, digits=6,target_names=binary_labels))
# Out:
#               precision    recall  f1-score   support
#
#       BENIGN   0.996395  0.998490  0.997442     18548
#       ATTACK   0.998487  0.996388  0.997437     18550
#
#     accuracy                       0.997439     37098
#    macro avg   0.997441  0.997439  0.997439     37098
# weighted avg   0.997441  0.997439  0.997439     37098

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

cm = confusion_matrix(y_test, pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=binary_labels)
fig, ax = plt.subplots(figsize=(12,12))
disp.plot(ax=ax)
plt.savefig("confusion_binary_lstm.png")
